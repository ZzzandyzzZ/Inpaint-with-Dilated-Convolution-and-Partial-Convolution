# %%
# !git clone https://github.com/YB221/Image-Inpainting-using-Partial-Convolutional-Layers.git
# Out:
# Cloning into 'Image-Inpainting-using-Partial-Convolutional-Layers'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 30 (delta 5), reused 30 (delta 5), pack-reused 0
# Unpacking objects: 100% (30/30), done.

# %%
# !cd Image-Inpainting-using-Partial-Convolutional-Layers/
# !ls
# Out:
# Image-Inpainting-using-Partial-Convolutional-Layers  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
#os.chdir("/content/drive/My Drive/UNSA/8 semestre/Proyecto fin de carrera/REPOSITORIO")
os.chdir("/content")
# !ls
# Out:
# drive  Image-Inpainting-using-Partial-Convolutional-Layers  sample_data

# %%
# !mv 'Image-Inpainting-using-Partial-Convolutional-Layers' '/content/drive/My Drive/UNSA/8 semestre/Proyecto fin de carrera/REPOSITORIO'
